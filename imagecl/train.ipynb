# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/imagecl/data/weather_dataset/'
# Out:
# bat.jpeg     randomimage.jpg  testchoco2.jpeg  train.cache  val.cache
# perk123.jpg  testchoco1.jpeg  train	       val	    zebra.jpg

# %%
DATA_DIR = '/content/gdrive/My Drive/imagecl/data/weather_dataset/'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 695.2/695.2 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n-cls.pt")  # load a pretained model

# Use the model
results = model.train(data=DATA_DIR, epochs=20, imgsz=640)  # train the model
# Out:
# ...
# 100%|██████████| 5.28M/5.28M [00:00<00:00, 61.5MB/s]
# Ultralytics YOLOv8.0.238 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/imagecl'

# %%
model = YOLO('/content/runs/classify/train/weights/best.pt')

# %%
results = model('/content/gdrive/MyDrive/imagecl/data/weather_dataset/testchoco2.jpeg')
# Out:
# image 1/1 /content/gdrive/MyDrive/imagecl/data/weather_dataset/testchoco2.jpeg: 64x64 other 1.00, perk 0.00, 4.0ms
# Speed: 10.9ms preprocess, 4.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)

# %%
pip install gradio

# %%
from tkinter import Button
import gradio as gr

def classify_image(results):
    labels_dict = results[0].names
    probs = results[0].probs.data.tolist()
    detected_objects = []

    for i in range(len(probs)):
        if probs[i]>0.80:
            detected_objects.append(results[0].names[i])
    return {"landmarks":list(detected_objects)}
iface = gr.Interface(
    fn=classify_image,
    inputs=gr.Image(label="Query image"),
    outputs="text",
    title="Image Classification for chocolate raper",
    description="Upload an image for classification.",
    theme="compact"
)

# Launch the interface
iface.launch()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-bad70e827a97> in <cell line: 2>()
#       1 from tkinter import Button
# ----> 2 import gradio as gr
#       3
#       4 def classify_image(results):
#       5     labels_dict = results[0].names
#
# /usr/local/lib/python3.10/dist-packages/gradio/__init__.py in <module>
#       1 import json
#       2
# ----> 3 import gradio._simple_templates
#       4 import gradio.components as components
#       5 import gradio.image_utils
#
# /usr/local/lib/python3.10/dist-packages/gradio/_simple_templates/__init__.py in <module>
# ----> 1 from .simpledropdown import SimpleDropdown
#       2 from .simpletextbox import SimpleTextbox
#       3
#       4 __all__ = ["SimpleDropdown", "SimpleTextbox"]
#
# /usr/local/lib/python3.10/dist-packages/gradio/_simple_templates/simpledropdown.py in <module>
# ...
